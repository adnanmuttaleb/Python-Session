# %%
import pandas as pd
import pandas_profiling

# %%
df = pd.read_csv('airbnb/AB_NYC_2019.csv')

# %%
df.sample(10)
# Out:
#              id                                               name    host_id  \
# 24607  19785737                                     Hillside Hotel  134184451
# 42734  33169890         Cozy Bedroom on Upper west near Columbia U  233917490
# 7101    5136673                Spacious Brooklyn Loft/private room    8118080
# 2546    1316961                     Huge Sunny Apt Hip/Family Area     772862
# 11573   9004946                      One bedroom garden apartment.   47025665
# 21935  17640413  Private room & living room, one block from sub...   44709817
# 1662     753687                                     Mitchell Manor    3964655
# 8571    6599302                    An ENTIRE, Lovely NYC Apartment   15386409
# 25447  20356797                       New York Apartment in Queens  127077398
# 31997  24970711                                    Budget Basement  188783370
#
#             host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
profile = df.profile_report(style={'full_width':True})

# %%
profile.to_file(output_file='airbnb/airbnb.html')
